# %% [markdown]
# # 1.验证 realloc 和 non-realloc 的性能差异
# - 什么是 realloc： 在选择完 sparse attention 之后，是否按照原来的权重w，重新计算 value，其中 value 会变成 w * SparseV + （1-我） * meanV
# - 验证的结果：
# ![性能测试结果](./mean_vs_withou_mean.png)

# %% [markdown]
# - 结果显示：
# - 1. vec realloc 明显比其他的要差，其他的都是 non-realloc
# - 2. 说明 realloc 没有起到好的效果！

# %% [markdown]
# # 延伸实验

# %% [markdown]
# # 测试 head 权重

# %% [markdown]
# # 测试硬件优化
