# %% [markdown]
# # 首先验证dense 和 dynmiac 的正确性！

# %%
import dense_1
dense_1_bpc = dense_1.run_dense_1()
print("dense bpc:", dense_1_bpc)
# Out:
# /home/sjq/miniconda3/envs/sparq/lib/python3.9/site-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
import dynamic_1
result = []
for sparisy in [1]:
    dynamic_1_bpc, dynamic_1_real_sparsity = dynamic_1.run_dynamic_1(sparisy)
    print("sparsity:", sparisy)
    print("dynamic bpc:", dynamic_1_bpc)
    print("dynamic real sparsity:", dynamic_1_real_sparsity)
    result.append((sparisy, dynamic_1_bpc, dynamic_1_real_sparsity))

for r in result:
    print("sparsity:", r[0], " dynamic bpc:", r[1], " dynamic real sparsity:", r[2])
# Out:
# /home/sjq/miniconda3/envs/sparq/lib/python3.9/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Dynamic!!!
# `trust_remote_code` is not supported anymore.
# Please check that the Hugging Face dataset 'EleutherAI/wikitext_document_level' isn't based on a loading script and remove `trust_remote_code`.
# If the dataset is based on a loading script, please ask the dataset author to remove it and convert it to a standard format like Parquet.
# Evaluating EleutherAI/pythia-410m:   0%|          | 0/1 [00:00<?, ?it/s]
# Error: name 'exit' is not defined
# Traceback (most recent call last):
# ...

# %%
import torch
dynamic_weight_debug = torch.load("dynamic_weight_debug.pt")
dense_weight_debug = torch.load("dense_weights_debug.pt")
print("dynamic weight max:", dynamic_weight_debug.max().item())
print("dense weight max:", dense_weight_debug.max().item())

pruned_weight_debug = torch.load("dynamic_pruned_weight_debug.pt")
print("pruned weight max:", pruned_weight_debug.max().item())
pruned_normalized_weight_debug = torch.load("dynamic_pruned_normalized_weight_debug.pt")
print("pruned normalized weight max:", pruned_normalized_weight_debug.max().item())

dense_output_debug = torch.load("dense_output_debug.pt")
print("dense output max:", dense_output_debug.max().item())
dynamic_output_debug = torch.load("dynamic_output_debug.pt")
print("dynamic output max:", dynamic_output_debug.max().item())

dense_value_debug = torch.load("dense_value_debug.pt")
print("dense value max:", dense_value_debug.std().item())
dynamic_value_debug = torch.load("dynamic_value_debug.pt")
print("dynamic value max:", dynamic_value_debug.std().item())

dense_raw_query_debug = torch.load("dense_raw_query_debug.pt")
print("dense raw query max:", dense_raw_query_debug.max().item())
dynamic_raw_query_debug = torch.load("dynamic_raw_query_debug.pt")
print("dynamic raw query max:", dynamic_raw_query_debug.max().item())

dense_raw_value_debug = torch.load("dense_raw_value_debug.pt")
print("dense raw value max:", dense_raw_value_debug.max().item())
dynamic_raw_value_debug = torch.load("dynamic_raw_value_debug.pt")
print("dynamic raw value max:", dynamic_raw_value_debug.max().item())
# Out:
# dynamic weight max: 0.33447265625
# dense weight max: 0.33447265625
# pruned weight max: 0.33447265625
# pruned normalized weight max: 0.33447265625
# dense output max: 0.455322265625
# dynamic output max: 0.455322265625
# dense value max: 0.434814453125
# dynamic value max: 0.434814453125
# dense raw query max: 10.3046875
# dynamic raw query max: 10.3046875
# dense raw value max: 4.59375
# dynamic raw value max: 4.59375

# %%
print("dense output max:    ", dense_output_debug)
print("dynamic output max:  ", dynamic_output_debug)
# Out:
# dense output max:     tensor([[[[ 0.0486, -0.1986, -0.0014,  ...,  0.1421, -0.1026, -0.0150]],
#
#          [[ 0.0606, -0.1681, -0.1378,  ..., -0.0210, -0.0288,  0.0872]],
#
#          [[-0.0754, -0.0713, -0.0078,  ...,  0.0207, -0.1353,  0.1138]],
#
#          ...,
#
#          [[-0.4492,  0.0038, -0.0208,  ...,  0.0101, -0.0833,  0.0069]],
#
#          [[-0.0083, -0.0043, -0.0908,  ...,  0.1259,  0.0082, -0.0405]],
#
#          [[ 0.0067, -0.0013,  0.0247,  ..., -0.0151,  0.0548,  0.0241]]]],
#        device='cuda:0', dtype=torch.float16)
# dynamic output max:   tensor([[[[[ 0.0486, -0.1986, -0.0014,  ...,  0.1421, -0.1026, -0.0150]]],
#
#
#          [[[ 0.0607, -0.1681, -0.1379,  ..., -0.0210, -0.0288,  0.0872]]],
#
#
#          [[[-0.0754, -0.0713, -0.0078,  ...,  0.0207, -0.1353,  0.1138]]],
#
#
#          ...,
#
#
#          [[[-0.4492,  0.0038, -0.0208,  ...,  0.0101, -0.0833,  0.0069]]],
#
#
#          [[[-0.0083, -0.0044, -0.0911,  ...,  0.1260,  0.0082, -0.0405]]],
#
#
# ...
